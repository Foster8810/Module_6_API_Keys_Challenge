# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID                     City      Lat       Lng  Max Temp  Humidity  \
# 0        0                   namibe -15.1961   12.1522     22.72        70
# 1        1        port-aux-francais -49.3500   70.2167      6.93        97
# 2        2                papatowai -46.5619  169.4708     10.72        73
# 3        3  puerto baquerizo moreno  -0.9000  -89.6000     23.69        88
# 4        4                 klaksvik  62.2266   -6.5890      4.51        76
#
#    Cloudiness  Wind Speed Country        Date
# 0           3        3.00      AO  1715039934
# 1         100       13.27      TF  1715039650
# 2          76        5.80      NZ  1715039935
# 3           7        3.41      EC  1715039935
# 4          49        5.15      FO  1715039935

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map1 = city_data_df.hvplot.points(
    'Lng',
    'Lat',
    geo = True,
    tiles = 'OSM',
    frame_width = 700,
    frame_height = 500,
    color = 'City')

# Display the map
map1
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
city_data_df = city_data_df[city_data_df['Cloudiness'] == 0]


# Drop any rows with null values
city_data_df.dropna()

# Display sample data
city_data_df
# Out:
#      City_ID             City      Lat       Lng  Max Temp  Humidity  \
# 13        13        carnarvon -24.8667  113.6333     19.60        59
# 18        18            tosno  59.5400   30.8775      1.90        78
# 29        29     mersa matruh  31.3525   27.2453     16.11        72
# 35        35             roma  43.2128  -75.4557     17.08        39
# 41        41  arraial do cabo -22.9661  -42.0278     23.98        88
# ..       ...              ...      ...       ...       ...       ...
# 520      520          chimoio -19.1164   33.4833     16.92       100
# 525      525        victorica -36.2151  -65.4359     11.84        92
# 532      532           orkney -26.9802   26.6727     15.10        26
# 548      548           gunjur  13.2019  -16.7339     24.04        88
# 560      560          kunming  25.0389  102.7183     12.96        62
#
#      Cloudiness  Wind Speed Country        Date
# 13            0        7.45      AU  1715039936
# 18            0        1.54      RU  1715039937
# 29            0        4.12      EG  1715039939
# 35            0        5.14      US  1715039736
# 41            0        5.66      BR  1715039664
# ..          ...         ...     ...         ...
# 520           0        0.74      MZ  1715040033
# 525           0        5.51      AR  1715040033
# 532           0        1.97      ZA  1715040035
# 548           0        1.54      GM  1715040038
# 560           0        1.00      CN  1715040005
#
# [83 rows x 10 columns]

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = pd.DataFrame({
    'City': city_data_df['City'],
    'Country': city_data_df['Country'],
    'Lat': city_data_df['Lat'],
    'Lng': city_data_df['Lng'],
    'Humidity': city_data_df['Humidity'],
})
# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ''

# Display sample data
hotel_df
# Out:
#                 City Country      Lat       Lng  Humidity Hotel Name
# 13         carnarvon      AU -24.8667  113.6333        59
# 18             tosno      RU  59.5400   30.8775        78
# 29      mersa matruh      EG  31.3525   27.2453        72
# 35              roma      US  43.2128  -75.4557        39
# 41   arraial do cabo      BR -22.9661  -42.0278        88
# ..               ...     ...      ...       ...       ...        ...
# 520          chimoio      MZ -19.1164   33.4833       100
# 525        victorica      AR -36.2151  -65.4359        92
# 532           orkney      ZA -26.9802   26.6727        26
# 548           gunjur      GM  13.2019  -16.7339        88
# 560          kunming      CN  25.0389  102.7183        62
#
# [83 rows x 6 columns]

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
radius = 10000
params = {
    'categories': 'accommodation.hotel',
    'apiKey': geoapify_key,
    'limit':20
}

    
 # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
params["filter"] = f"circle:{102.7183},{25.0389},{radius}"
params["bias"] = f"proximity:{102.7183},{25.0389}"
    
    # Set base URL
base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
name_address = name_address.json()
name_address
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'name': '海韵艺术酒店',
#     'country': 'China',
#     'country_code': 'cn',
#     'state': 'Yunnan',
#     'city': 'Kunming',
#     'postcode': '650051',
#     'district': 'Wuhua District',
#     'suburb': 'Huguo Subdistrict',
#     'street': 'Qingnian Road',
#     'lon': 102.7154209,
#     'lat': 25.0396175,
#     'formatted': 'Hai Yun Hotel, Qingnian Road, Huguo Subdistrict, 650051 Yunnan, China',
#     'address_line1': 'Hai Yun Hotel',
#     'address_line2': 'Qingnian Road, Huguo Subdistrict, 650051 Yunnan, China',
#     'categories': ['accommodation', 'accommodation.hotel'],
#     'details': ['details'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database License',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': '海韵艺术酒店',
#       'osm_id': 10672149560,
#       'name:en': 'Hai Yun Hotel',
#       'tourism': 'hotel',
#       'osm_type': 'n'}},
#     'name_international': {'en': 'Hai Yun Hotel'},
#     'distance': 301,
#     'place_id': '51fe17be74c9ad59405954f15b5f240a3940f00103f90138141c7c02000000920312e6b5b7e99fb5e889bae69cafe98592e5ba97'},
#    'geometry': {'type': 'Point',
#     'coordinates': [102.7154209, 25.03961750025458]}},
#   {'type': 'Feature',
#    'properties': {'name': '邦克饭店',
#     'country': 'China',
#     'country_code': 'cn',
#     'state': 'Yunnan',
#     'city': 'Kunming',
#     'postcode': '650051',
#     'district': 'Wuhua District',
#     'suburb': 'Huguo Subdistrict',
#     'street': 'Qingnian Road',
#     'lon': 102.7154877,
#     'lat': 25.0372405,
#     'formatted': 'Bank Hotel, Qingnian Road, Huguo Subdistrict, 650051 Yunnan, China',
#     'address_line1': 'Bank Hotel',
#     'address_line2': 'Qingnian Road, Huguo Subdistrict, 650051 Yunnan, China',
#     'categories': ['accommodation', 'accommodation.hotel'],
#     'details': ['details'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database License',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': '邦克饭店',
#       'osm_id': 474616361,
#       'name:en': 'Bank Hotel',
#       'tourism': 'hotel',
#       'osm_type': 'n'}},
#     'name_international': {'en': 'Bank Hotel'},
#     'distance': 338,
#     'place_id': '512c0cec8ccaad59405955aeea9788093940f00103f90129124a1c0000000092030ce982a6e5858be9a5ade5ba97'},
#    'geometry': {'type': 'Point',
#     'coordinates': [102.71548769999998, 25.037240500254786]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Fairyland Hotel Dongfeng Plaza',
#     'country': 'China',
#     'country_code': 'cn',
#     'state': 'Yunnan',
#     'city': 'Kunming',
#     'postcode': '650051',
#     'district': 'Panlong District',
#     'suburb': 'Tuodong Subdistrict',
#     'street': 'Beijing Road',
#     'lon': 102.7185461,
#     'lat': 25.042127,
#     'formatted': 'Fairyland Hotel Dongfeng Plaza, Beijing Road, Tuodong Subdistrict, 650051 Yunnan, China',
#     'address_line1': 'Fairyland Hotel Dongfeng Plaza',
#     'address_line2': 'Beijing Road, Tuodong Subdistrict, 650051 Yunnan, China',
#     'categories': ['accommodation',
#      'accommodation.hotel',
#      'internet_access',
#      'internet_access.free'],
#     'details': ['details', 'details.accommodation', 'details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database License',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'stars': 3,
#       'osm_id': 2774690560,
#       'name:en': 'Fairyland Hotel Dongfeng Plaza',
#       'tourism': 'hotel',
#       'osm_type': 'n',
#       'internet_access': 'yes',
#       'internet_access:fee': 'no'}},
#     'name_international': {'en': 'Fairyland Hotel Dongfeng Plaza'},
#     'facilities': {'internet_access': True},
#     'accommodation': {'stars': 3},
#     'distance': 358,
#     'place_id': '51c60ac8a8fcad594059025fc8d5c80a3940f00103f901006b62a500000000'},
#    'geometry': {'type': 'Point',
#     'coordinates': [102.7185461, 25.042127000254375]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Horizon Hotel',
#     'country': 'China',
#     'country_code': 'cn',
#     'state': 'Yunnan',
#     'city': 'Kunming',
#     'postcode': '650051',
#     'district': 'Wuhua District',
#     'suburb': 'Huguo Subdistrict',
#     'street': 'Qingnian Road',
#     'lon': 102.7144179906607,
#     'lat': 25.04007285,
#     'formatted': 'Horizon Hotel, Qingnian Road, Huguo Subdistrict, 650051 Yunnan, China',
#     'address_line1': 'Horizon Hotel',
#     'address_line2': 'Qingnian Road, Huguo Subdistrict, 650051 Yunnan, China',
#     'categories': ['accommodation',
#      'accommodation.hotel',
#      'building',
#      'building.accommodation'],
#     'details': ['details'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database License',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'osm_id': 273899631,
#       'name:en': 'Horizon Hotel',
#       'tourism': 'hotel',
#       'building': 'yes',
#       'osm_type': 'w'}},
#     'name_international': {'en': 'Horizon Hotel'},
#     'distance': 369,
#     'place_id': '51f4633c06b9ad594059024ddd36420a3940f00102f9016f60531000000000'},
#    'geometry': {'type': 'Point',
#     'coordinates': [102.7144179906607, 25.040072850254553]}},
#   {'type': 'Feature',
#    'properties': {'country': 'China',
#     'country_code': 'cn',
#     'state': 'Yunnan',
#     'city': 'Kunming',
#     'postcode': '650011',
#     'district': 'Guandu District',
#     'suburb': 'Taihe Subdistrict',
#     'street': 'WuJin Road',
#     'lon': 102.7193822,
#     'lat': 25.0349512,
#     'formatted': 'WuJin Road, Taihe Subdistrict, 650011 Yunnan, China',
#     'address_line1': 'WuJin Road',
#     'address_line2': 'Taihe Subdistrict, 650011 Yunnan, China',
#     'categories': ['accommodation', 'accommodation.hotel'],
#     'details': [],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database License',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'osm_id': 6067849392, 'tourism': 'hotel', 'osm_type': 'n'}},
#     'distance': 451,
#     'place_id': '51c594a35b0aae594059170dd68ff2083940f00103f901b008ac6901000000'},
#    'geometry': {'type': 'Point',
#     'coordinates': [102.7193822, 25.03495120025499]}},
#   {'type': 'Feature',
#    'properties': {'name': '城市之心',
#     'country': 'China',
#     'country_code': 'cn',
#     'state': 'Yunnan',
#     'city': 'Kunming',
#     'postcode': '650051',
#     'district': 'Wuhua District',
#     'suburb': 'Huguo Subdistrict',
#     'street': 'Huguo Road',
#     'lon': 102.71327744596817,
#     'lat': 25.0394352,
#     'formatted': '城市之心, Huguo Road, Huguo Subdistrict, 650051 Yunnan, China',
#     'address_line1': '城市之心',
#     'address_line2': 'Huguo Road, Huguo Subdistrict, 650051 Yunnan, China',
#     'categories': ['accommodation',
#      'accommodation.hotel',
#      'building',
#      'building.accommodation'],
#     'details': [],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database License',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': '城市之心',
#       'osm_id': 437227740,
#       'tourism': 'hotel',
#       'building': 'yes',
#       'osm_type': 'w'}},
#     'distance': 477,
#     'place_id': '5117da7156a6ad5940599d67df6c180a3940f00102f901dc900f1a0000000092030ce59f8ee5b882e4b98be5bf83'},
#    'geometry': {'type': 'Point',
#     'coordinates': [102.71327744596816, 25.039435200254605]}},
#   {'type': 'Feature',
#    'properties': {'name': '昆明中心假日酒店',
#     'country': 'China',
#     'country_code': 'cn',
#     'state': 'Yunnan',
#     'city': 'Kunming',
#     'postcode': '650011',
#     'district': 'Panlong District',
#     'suburb': 'Tuodong Subdistrict',
#     'street': 'Baita Road',
#     'lon': 102.72331850650147,
#     'lat': 25.0405654,
#     'formatted': '昆明中心假日酒店, Baita Road, Tuodong Subdistrict, 650011 Yunnan, China',
#     'address_line1': '昆明中心假日酒店',
#     'address_line2': 'Baita Road, Tuodong Subdistrict, 650011 Yunnan, China',
#     'categories': ['accommodation',
#      'accommodation.hotel',
#      'building',
#      'building.accommodation'],
#     'details': ['details'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database License',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': '昆明中心假日酒店',
#       'brand': 'Holiday Inn',
#       'osm_id': 1040140506,
#       'tourism': 'hotel',
#       'building': 'hotel',
#       'osm_type': 'w',
#       'brand:wikidata': 'Q2717882',
#       'brand:wikipedia': 'en:Holiday Inn'}},
#     'brand': 'Holiday Inn',
#     'brand_details': {'wikidata': 'Q2717882', 'wikipedia': 'en:Holiday Inn'},
#     'building': {'type': 'hotel'},
#     'distance': 488,
#     'place_id': '51fc80b4d94aae59405938717b7e620a3940f00102f901da48ff3d00000000920318e69886e6988ee4b8ade5bf83e58187e697a5e98592e5ba97'},
#    'geometry': {'type': 'Point',
#     'coordinates': [102.72331850650147, 25.040565400254508]}},
#   {'type': 'Feature',
#    'properties': {'country': 'China',
#     'country_code': 'cn',
#     'state': 'Yunnan',
#     'city': 'Kunming',
#     'postcode': '650051',
#     'district': 'Wuhua District',
#     'suburb': 'Huguo Subdistrict',
#     'street': 'Dongfeng East Road',
#     'lon': 102.7142774,
#     'lat': 25.0413991,
#     'formatted': 'Dongfeng East Road, Huguo Subdistrict, 650051 Yunnan, China',
#     'address_line1': 'Dongfeng East Road',
#     'address_line2': 'Huguo Subdistrict, 650051 Yunnan, China',
#     'categories': ['accommodation', 'accommodation.hotel'],
#     'details': [],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database License',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'osm_id': 6069827685, 'tourism': 'hotel', 'osm_type': 'n'}},
#     'distance': 491,
#     'place_id': '5166518eb8b6ad5940593bada521990a3940f00103f9016538ca6901000000'},
#    'geometry': {'type': 'Point',
#     'coordinates': [102.71427739999999, 25.04139910025445]}},
#   {'type': 'Feature',
#    'properties': {'country': 'China',
#     'country_code': 'cn',
#     'state': 'Yunnan',
#     'city': 'Kunming',
#     'postcode': '650051',
#     'district': 'Panlong District',
#     'suburb': 'Tuodong Subdistrict',
#     'street': 'Beijing Road',
#     'lon': 102.71692582374567,
#     'lat': 25.043967199999997,
#     'formatted': 'Beijing Road, Tuodong Subdistrict, 650051 Yunnan, China',
#     'address_line1': 'Beijing Road',
#     'address_line2': 'Tuodong Subdistrict, 650051 Yunnan, China',
#     'categories': ['accommodation',
#      'accommodation.hotel',
#      'building',
#      'building.accommodation',
#      'internet_access'],
#     'details': ['details.accommodation', 'details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database License',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'stars': 4,
#       'osm_id': 1059164640,
#       'tourism': 'hotel',
#       'building': 'hotel',
#       'osm_type': 'w',
#       'internet_access': 'wlan'}},
#     'facilities': {'internet_access': True},
#     'accommodation': {'stars': 4},
#     'building': {'type': 'hotel'},
#     'distance': 543,
#     'place_id': '5150a9d91ce2ad5940594430376f410b3940f00102f901e091213f00000000'},
#    'geometry': {'type': 'Point',
#     'coordinates': [102.71692582374567, 25.043967200254215]}},
#   {'type': 'Feature',
#    'properties': {'name': '绿洲大酒店',
#     'country': 'China',
#     'country_code': 'cn',
#     'state': 'Yunnan',
#     'city': 'Kunming',
#     'postcode': '650011',
#     'district': 'Panlong District',
#     'suburb': 'Tuodong Subdistrict',
#     'street': 'Tuodong Road',
#     'lon': 102.7237129,
#     'lat': 25.0368641,
#     'formatted': 'Green Land Hotel, Tuodong Road, Tuodong Subdistrict, 650011 Yunnan, China',
#     'address_line1': 'Green Land Hotel',
#     'address_line2': 'Tuodong Road, Tuodong Subdistrict, 650011 Yunnan, China',
#     'categories': ['accommodation', 'accommodation.hotel'],
#     'details': ['details'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database License',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': '绿洲大酒店',
#       'osm_id': 434321486,
#       'name:en': 'Green Land Hotel',
#       'tourism': 'hotel',
#       'osm_type': 'n'}},
#     'name_international': {'en': 'Green Land Hotel'},
#     'distance': 591,
#     'place_id': '515f4ce94f51ae594059aefdf8ec6f093940f00103f9014e38e3190000000092030fe7bbbfe6b4b2e5a4a7e98592e5ba97'},
#    'geometry': {'type': 'Point',
#     'coordinates': [102.7237129, 25.036864100254824]}},
#   {'type': 'Feature',
#    'properties': {'country': 'China',
#     'country_code': 'cn',
#     'state': 'Yunnan',
#     'city': 'Kunming',
#     'postcode': '650011',
#     'district': 'Guandu District',
#     'suburb': 'Taihe Subdistrict',
#     'street': 'WuJin Road',
#     'lon': 102.720584,
#     'lat': 25.0336573,
#     'formatted': 'WuJin Road, Taihe Subdistrict, 650011 Yunnan, China',
#     'address_line1': 'WuJin Road',
#     'address_line2': 'Taihe Subdistrict, 650011 Yunnan, China',
#     'categories': ['accommodation', 'accommodation.hotel'],
#     'details': [],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database License',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'osm_id': 6067834893, 'tourism': 'hotel', 'osm_type': 'n'}},
#     'distance': 625,
#     'place_id': '5156815a0c1eae59405908decbc39d083940f00103f9010dd0ab6901000000'},
#    'geometry': {'type': 'Point',
#     'coordinates': [102.720584, 25.0336573002551]}},
#   {'type': 'Feature',
#    'properties': {'name': '同玥酒店',
#     'country': 'China',
#     'country_code': 'cn',
#     'state': 'Yunnan',
#     'city': 'Kunming',
#     'postcode': '650051',
#     'district': 'Wuhua District',
#     'suburb': 'Huguo Subdistrict',
#     'street': 'Qingyun Street',
#     'lon': 102.7128124,
#     'lat': 25.0415737,
#     'formatted': '同玥酒店, Qingyun Street, Huguo Subdistrict, 650051 Yunnan, China',
#     'address_line1': '同玥酒店',
#     'address_line2': 'Qingyun Street, Huguo Subdistrict, 650051 Yunnan, China',
#     'categories': ['accommodation', 'accommodation.hotel'],
#     'details': [],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database License',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': '同玥酒店',
#       'level': 4,
#       'osm_id': 11029669186,
#       'tourism': 'hotel',
#       'osm_type': 'n'}},
#     'distance': 628,
#     'place_id': '51bb8be6b79ead59405969f7f292a40a3940f00103f90142656b910200000092030ce5908ce78ea5e98592e5ba97'},
#    'geometry': {'type': 'Point',
#     'coordinates': [102.7128124, 25.04157370025442]}},
#   {'type': 'Feature',
#    'properties': {'name': '昆明饭店',
#     'country': 'China',
#     'country_code': 'cn',
#     'state': 'Yunnan',
#     'city': 'Kunming',
#     'postcode': '650011',
#     'district': 'Panlong District',
#     'suburb': 'Tuodong Subdistrict',
#     'street': 'Baita Road',
#     'lon': 102.7235251,
#     'lat': 25.04222,
#     'formatted': 'Kunming Hotel, Baita Road, Tuodong Subdistrict, 650011 Yunnan, China',
#     'address_line1': 'Kunming Hotel',
#     'address_line2': 'Baita Road, Tuodong Subdistrict, 650011 Yunnan, China',
#     'categories': ['accommodation', 'accommodation.hotel'],
#     'details': ['details'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database License',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': '昆明饭店',
#       'osm_id': 434320988,
#       'name:en': 'Kunming Hotel',
#       'tourism': 'hotel',
#       'osm_type': 'n'}},
#     'name_international': {'en': 'Kunming Hotel'},
#     'distance': 643,
#     'place_id': '517395383c4eae594059605410eece0a3940f00103f9015c36e3190000000092030ce69886e6988ee9a5ade5ba97'},
#    'geometry': {'type': 'Point',
#     'coordinates': [102.7235251, 25.04222000025436]}},
#   {'type': 'Feature',
#    'properties': {'name': '7天酒店',
#     'country': 'China',
#     'country_code': 'cn',
#     'state': 'Yunnan',
#     'city': 'Kunming',
#     'postcode': '650011',
#     'district': 'Guandu District',
#     'suburb': 'Taihe Subdistrict',
#     'street': 'WuJin Road',
#     'lon': 102.7201699,
#     'lat': 25.0333294,
#     'formatted': '7 Days Inn, WuJin Road, Taihe Subdistrict, 650011 Yunnan, China',
#     'address_line1': '7 Days Inn',
#     'address_line2': 'WuJin Road, Taihe Subdistrict, 650011 Yunnan, China',
#     'categories': ['accommodation', 'accommodation.hotel'],
#     'details': ['details'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database License',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': '7天酒店',
#       'brand': '7天酒店',
#       'branch': '塘子巷地铁站店',
#       'osm_id': 4716223367,
#       'name:en': '7 Days Inn',
#       'name:zh': '7天酒店',
#       'tourism': 'hotel',
#       'brand:en': '7 Days Inn',
#       'brand:zh': '7天酒店',
#       'osm_type': 'n',
#       'brand:wikidata': 'Q4643844',
#       'brand:wikipedia': 'zh:7天酒店'}},
#     'brand': '7天酒店',
#     'brand_details': {'wikidata': 'Q4643844', 'wikipedia': 'zh:7天酒店'},
#     'branch': '塘子巷地铁站店',
#     'name_international': {'en': '7 Days Inn', 'zh': '7天酒店'},
#     'distance': 645,
#     'place_id': '5112047e4317ae59405950178c4688083940f00103f90187db1b190100000092030a37e5a4a9e98592e5ba97'},
#    'geometry': {'type': 'Point',
#     'coordinates': [102.7201699, 25.033329400255127]}},
#   {'type': 'Feature',
#    'properties': {'country': 'China',
#     'country_code': 'cn',
#     'state': 'Yunnan',
#     'city': 'Kunming',
#     'postcode': '650011',
#     'district': 'Panlong District',
#     'suburb': 'Tuodong Subdistrict',
#     'street': 'Baita Road',
#     'lon': 102.7244371,
#     'lat': 25.040728,
#     'formatted': 'Baita Road, Tuodong Subdistrict, 650011 Yunnan, China',
#     'address_line1': 'Baita Road',
#     'address_line2': 'Tuodong Subdistrict, 650011 Yunnan, China',
#     'categories': ['accommodation', 'accommodation.hotel'],
#     'details': [],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database License',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'osm_id': 434321783, 'tourism': 'hotel', 'osm_type': 'n'}},
#     'distance': 652,
#     'place_id': '5194206d2d5dae594059e11f75266d0a3940f00103f9017739e31900000000'},
#    'geometry': {'type': 'Point',
#     'coordinates': [102.72443709999999, 25.040728000254493]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Tenho hotel kunming',
#     'country': 'China',
#     'country_code': 'cn',
#     'state': 'Yunnan',
#     'city': 'Xishan District',
#     'postcode': '650011',
#     'suburb': 'Jinbi Subdistrict',
#     'street': 'Jinbi Road',
#     'lon': 102.711408,
#     'lat': 25.0360031,
#     'formatted': 'Tenho hotel kunming, Jinbi Road, Jinbi Subdistrict, 650011 Yunnan, China',
#     'address_line1': 'Tenho hotel kunming',
#     'address_line2': 'Jinbi Road, Jinbi Subdistrict, 650011 Yunnan, China',
#     'categories': ['accommodation', 'accommodation.hotel', 'internet_access'],
#     'details': ['details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database License',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Tenho hotel kunming',
#       'osm_id': 6147255285,
#       'tourism': 'hotel',
#       'osm_type': 'n',
#       'addr:street': '金碧路',
#       'internet_access': 'wlan'}},
#     'facilities': {'internet_access': True},
#     'distance': 766,
#     'place_id': '5138876bb587ad5940594126ca7f37093940f00103f901f5ab676e0100000092031354656e686f20686f74656c206b756e6d696e67'},
#    'geometry': {'type': 'Point',
#     'coordinates': [102.711408, 25.036003100254906]}},
#   {'type': 'Feature',
#    'properties': {'name': '金鹰广场酒店',
#     'country': 'China',
#     'country_code': 'cn',
#     'state': 'Yunnan',
#     'city': 'Kunming',
#     'postcode': '650051',
#     'district': 'Wuhua District',
#     'suburb': 'Huguo Subdistrict',
#     'street': '财盛巷',
#     'lon': 102.7120426,
#     'lat': 25.0433282,
#     'formatted': '金鹰广场酒店, 财盛巷, Huguo Subdistrict, 650051 Yunnan, China',
#     'address_line1': '金鹰广场酒店',
#     'address_line2': '财盛巷, Huguo Subdistrict, 650051 Yunnan, China',
#     'categories': ['accommodation', 'accommodation.hotel'],
#     'details': [],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database License',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': '金鹰广场酒店',
#       'osm_id': 10722735416,
#       'tourism': 'hotel',
#       'osm_type': 'n'}},
#     'distance': 800,
#     'place_id': '51f616201b92ad5940592e16938e170b3940f00103f90138f51f7f02000000920312e98791e9b9b0e5b9bfe59cbae98592e5ba97'},
#    'geometry': {'type': 'Point',
#     'coordinates': [102.71204259999999, 25.043328200254273]}},
#   {'type': 'Feature',
#    'properties': {'name': '金泉大酒店',
#     'country': 'China',
#     'country_code': 'cn',
#     'state': 'Yunnan',
#     'city': 'Kunming',
#     'postcode': '650051',
#     'district': 'Panlong District',
#     'suburb': 'Tuodong Subdistrict',
#     'street': 'Renmin East Road',
#     'housenumber': '97',
#     'lon': 102.7217843,
#     'lat': 25.0454644,
#     'formatted': '金泉大酒店, 97 Renmin East Road, Tuodong Subdistrict, 650051 Yunnan, China',
#     'address_line1': '金泉大酒店',
#     'address_line2': '97 Renmin East Road, Tuodong Subdistrict, 650051 Yunnan, China',
#     'categories': ['accommodation', 'accommodation.hotel'],
#     'details': ['details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database License',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': '金泉大酒店',
#       'osm_id': 3165901320,
#       'smoking': 'outside',
#       'tourism': 'hotel',
#       'osm_type': 'n',
#       'addr:city': '昆明',
#       'addr:street': '人民东路',
#       'addr:postcode': 650051,
#       'addr:street:en': 'Renmin East Road',
#       'addr:street:zh': '人民东路',
#       'addr:housenumber': 97}},
#     'facilities': {'smoking': True},
#     'distance': 808,
#     'place_id': '510ad1c6b631ae5940593c39108ea30b3940f00103f90108d2b3bc0000000092030fe98791e6b389e5a4a7e98592e5ba97'},
#    'geometry': {'type': 'Point',
#     'coordinates': [102.7217843, 25.04546440025409]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Youth Harbour',
#     'country': 'China',
#     'country_code': 'cn',
#     'state': 'Yunnan',
#     'city': 'Kunming',
#     'postcode': '650051',
#     'district': 'Wuhua District',
#     'suburb': 'Huguo Subdistrict',
#     'street': '财盛巷',
#     'lon': 102.7119294,
#     'lat': 25.0433325,
#     'formatted': 'Youth Harbour, 财盛巷, Huguo Subdistrict, 650051 Yunnan, China',
#     'address_line1': 'Youth Harbour',
#     'address_line2': '财盛巷, Huguo Subdistrict, 650051 Yunnan, China',
#     'categories': ['accommodation', 'accommodation.hotel'],
#     'details': ['details'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database License',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'osm_id': 4431024991,
#       'name:en': 'Youth Harbour',
#       'tourism': 'hotel',
#       'osm_type': 'n'}},
#     'name_international': {'en': 'Youth Harbour'},
#     'distance': 809,
#     'place_id': '51e683544090ad5940592d72b7d6170b3940f00103f9015f131c0801000000'},
#    'geometry': {'type': 'Point',
#     'coordinates': [102.7119294, 25.04333250025427]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Ibis',
#     'country': 'China',
#     'country_code': 'cn',
#     'state': 'Yunnan',
#     'city': 'Kunming',
#     'postcode': '650051',
#     'district': 'Guandu District',
#     'suburb': 'Taihe Subdistrict',
#     'street': 'Beijing Road',
#     'lon': 102.7185849,
#     'lat': 25.0315853,
#     'formatted': 'Ibis, Beijing Road, Taihe Subdistrict, 650051 Yunnan, China',
#     'address_line1': 'Ibis',
#     'address_line2': 'Beijing Road, Taihe Subdistrict, 650051 Yunnan, China',
#     'categories': ['accommodation', 'accommodation.hotel'],
#     'details': ['details'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database License',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Ibis',
#       'brand': 'Ibis',
#       'osm_id': 7127905080,
#       'tourism': 'hotel',
#       'osm_type': 'n',
#       'brand:wikidata': 'Q920166',
#       'brand:wikipedia': 'en:Ibis (hotel)'}},
#     'brand': 'Ibis',
#     'brand_details': {'wikidata': 'Q920166', 'wikipedia': 'en:Ibis (hotel)'},
#     'distance': 811,
#     'place_id': '519039854bfdad5940597aa167f915083940f00103f9013833dba80100000092030449626973'},
#    'geometry': {'type': 'Point',
#     'coordinates': [102.7185849, 25.03158530025528]}}]}

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    'categories': 'accommodation.hotel',
    'apiKey': geoapify_key,
    'limit':20
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    longitude = row['Lng']
    latitude = row['Lat']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# carnarvon - nearest hotel: No hotel found
# tosno - nearest hotel: Комфорт
# mersa matruh - nearest hotel: صقور
# roma - nearest hotel: Wingate by Wyndham Rome
# arraial do cabo - nearest hotel: No hotel found
# port augusta - nearest hotel: Hotel Commonwealth
# al kharijah - nearest hotel: Kharga Hotel
# anadyr - nearest hotel: Гостевой дом
# port lincoln - nearest hotel: Boston Hotel
# carthage - nearest hotel: Hôtel Amilcar
# sakakah - nearest hotel: فندق النزل
# hami - nearest hotel: Хами
# naantali - nearest hotel: Hotel Bridget Inn
# ghazni - nearest hotel: No hotel found
# luderitz - nearest hotel: Seaview Hotel Zum Sperrgebiet
# am timan - nearest hotel: Nimla
# hun - nearest hotel: فندق الهروج
# purna - nearest hotel: No hotel found
# ilhabela - nearest hotel: Vila Kebaya
# khanty-mansiysk - nearest hotel: Гамма
# pisco - nearest hotel: La Portada
# bredasdorp - nearest hotel: Victoria Hotel
# inebolu - nearest hotel: osman sungur
# tsiombe - nearest hotel: No hotel found
# holmen - nearest hotel: Prairie Inn & Suites
# hennenman - nearest hotel: No hotel found
# lompoc - nearest hotel: Red Roof Inn Lompoc
# east london - nearest hotel: No hotel found
# el bauga - nearest hotel: No hotel found
# chandler - nearest hotel: Crowne Plaza - San Marcos Golf Resort
# toliara - nearest hotel: Ambary
# beroroha - nearest hotel: No hotel found
# pasni - nearest hotel: Juddi Hotel
# walvis bay - nearest hotel: Atlantic
# forbes - nearest hotel: No hotel found
# phalaborwa - nearest hotel: Hans Merensky Hotel & Estate
# naukot - nearest hotel: No hotel found
# port alfred - nearest hotel: No hotel found
# mariental - nearest hotel: Mariental Hotel
# bodrum - nearest hotel: Costa Maya Bodrum
# laguna - nearest hotel: Holiday Inn Express & Suites
# carmo do paranaiba - nearest hotel: Hotel Panorâmico
# vallenar - nearest hotel: Hotel del Marqués
# dehu - nearest hotel: Courtyard Marriott
# tazacorte - nearest hotel: App Leyma
# jamestown - nearest hotel: DoubleTree Jamestown
# tindouf - nearest hotel: محمد بوسبي
# malone - nearest hotel: No hotel found
# puerto real - nearest hotel: Hostal Bahía de Cádiz
# naracoorte - nearest hotel: Kincraig Hotel /Smith & Jones Cafe
# coquimbo - nearest hotel: Hotel Iberia
# nkowakowa - nearest hotel: Tzaneen Country Lodge
# egilsstadir - nearest hotel: Valaskjálf
# shizuishan - nearest hotel: No hotel found
# queenstown - nearest hotel: Queens Hotel
# khorixas - nearest hotel: iGowati Country Hotel and Lodge
# dalbandin - nearest hotel: SF Al-dawood Restaurant
# saugor - nearest hotel: No hotel found
# oranjemund - nearest hotel: Op My Stoep
# opuwo - nearest hotel: Ohakane Lodge
# al ghayzah - nearest hotel: فندق تاج العرب
# saint-louis - nearest hotel: No hotel found
# dazhong - nearest hotel: No hotel found
# limassol - nearest hotel: Pefkos hotel
# upington - nearest hotel: Die Eiland Holiday Ressort
# calama - nearest hotel: Apart Hotel Geotel Calama
# ramon' - nearest hotel: Загородный отель "Путь к себе"
# tank - nearest hotel: No hotel found
# jhabua - nearest hotel: No hotel found
# pokaran - nearest hotel: Pokaran Desert Resort
# metlili chaamba - nearest hotel: No hotel found
# ogdensburg - nearest hotel: Dewar's Inn on the River
# al mindak - nearest hotel: No hotel found
# ramotswa - nearest hotel: No hotel found
# chilecito - nearest hotel: Hermosina Hotel
# mochudi - nearest hotel: Rasesa Lodge
# dubbo - nearest hotel: Blue Gum Motel
# civril - nearest hotel: Emre
# chimoio - nearest hotel: Hotel Amirana
# victorica - nearest hotel: Hotel Mazamet
# orkney - nearest hotel: No hotel found
# gunjur - nearest hotel: Footsteps Eco Lodge
# kunming - nearest hotel: 海韵艺术酒店
#                 City Country      Lat       Lng  Humidity  \
# 13         carnarvon      AU -24.8667  113.6333        59
# 18             tosno      RU  59.5400   30.8775        78
# 29      mersa matruh      EG  31.3525   27.2453        72
# 35              roma      US  43.2128  -75.4557        39
# 41   arraial do cabo      BR -22.9661  -42.0278        88
# ..               ...     ...      ...       ...       ...
# 520          chimoio      MZ -19.1164   33.4833       100
# 525        victorica      AR -36.2151  -65.4359        92
# 532           orkney      ZA -26.9802   26.6727        26
# 548           gunjur      GM  13.2019  -16.7339        88
# 560          kunming      CN  25.0389  102.7183        62
#
#                   Hotel Name
# 13            No hotel found
# 18                   Комфорт
# 29                      صقور
# 35   Wingate by Wyndham Rome
# 41            No hotel found
# ..                       ...
# 520            Hotel Amirana
# 525            Hotel Mazamet
# 532           No hotel found
# 548      Footsteps Eco Lodge
# 560                   海韵艺术酒店
#
# [83 rows x 6 columns]

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map2 = hotel_df.hvplot.points(
    'Lng',
    'Lat',
    geo = True,
    tiles = 'OSM',
    frame_width = 800,
    frame_height = 600,
    color = 'City',
    hover_cols = ['Hotel Name','Country']
)

# Display the map
map2
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Hotel Name,Country)
